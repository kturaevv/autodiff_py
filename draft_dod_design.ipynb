# %%
import enum


class Data:
    data: list[int] = []
    grad: list[int] = []
    op: list[int] = [] # fn pointer to operation
    fn: list[int] = []

    def __repr__(self) -> str:
        print(self.data, self.grad, self.op, self.fn, sep="\n")
        return ""
    
storage = Data()


class Scalar:
    def __init__(self, data = 0, grad = 0):
        self.data = data
        self.grad = grad

    def __add__(self, other):
        if not isinstance(other, Scalar):
            other = Scalar(other)

        storage.data.append(self.data)
        storage.data.append(other.data)
        storage.grad.append(self.grad)

        def backward(self, d_out):
            return d_out, d_out
        
        storage.op.append(Operations.add)
        storage.fn.append(backward)
        return Scalar(self.data + other.data)

    def __mul__(self, other):
        if not isinstance(other, Scalar):
            other = Scalar(other)

        storage.data.append(self.data)
        storage.data.append(other.data)
        storage.grad.append(self.grad)


        def backward(self, d_out):
            return other * d_out, self * d_out

        storage.op.append(Operations.mul)
        storage.fn.append(backward)
        return Scalar(self.data * other.data)

    def __pow__(self, other):

        storage.data.append(self.data)
        storage.grad.append(self.grad)

        def backward(self, d_out):
            return other * (self ** (other - 1)) * d_out

        storage.op.append(Operations.pow)
        storage.fn.append(backward)
        return Scalar(self.data ** other)

    # 
    
    def __neg__(self):  # -self
        return self * -1

    def __radd__(self, other):  # other + self
        return self + other

    def __rmul__(self, other):  # other * self
        return self * other

    def __sub__(self, other):  # self - other
        return self + (-other)

    def __rsub__(self, other):  # other - self
        return other + (-self)

    def __truediv__(self, other):  # self / other
        return self * other**-1

    def __rtruediv__(self, other):  # other / self
        return other * self**-1

    def __repr__(self):
        return "Scalar(data=%s,grad=%s)" % (self.data, self.grad)

    def build(self):
        """ Transfer OOP data from each Scalar instance to DOD array"""
        return

    def backward(self):
        return


class Operations(enum.Enum):
    add = Scalar.__add__
    mul = Scalar.__mul__
    pow = Scalar.__pow__

a, b, c, d, e = [ Scalar(i) for i in range(1, 6) ]

result = a * b + c - d / e
print(result)
result.backward()
storage
# Out:
# Scalar(data=4.2,grad=0)
# [1, 2, 2, 3, 5, 4, 0.2, 0.8, -1, 5, -0.8]
# [0, 0, 0, 0, 0, 0]
# [<function Scalar.__mul__ at 0x7f533043f2e0>, <function Scalar.__add__ at 0x7f53304431a0>, <function Scalar.__pow__ at 0x7f533043f240>, <function Scalar.__mul__ at 0x7f533043f2e0>, <function Scalar.__mul__ at 0x7f533043f2e0>, <function Scalar.__add__ at 0x7f53304431a0>]
# [<function Scalar.__mul__.<locals>.backward at 0x7f5330443740>, <function Scalar.__add__.<locals>.backward at 0x7f5321f5cc20>, <function Scalar.__pow__.<locals>.backward at 0x7f5321f5c680>, <function Scalar.__mul__.<locals>.backward at 0x7f5321f5c720>, <function Scalar.__mul__.<locals>.backward at 0x7f5321f5cea0>, <function Scalar.__add__.<locals>.backward at 0x7f5321f5cf40>]
